# %% [markdown]
# # Getting started with the Data API

# %% [markdown]
# ### **Let's search & download some imagery of farmland near Stockton, CA. Here are the steps we'll follow:**
#
# 1. Define an Area of Interest (AOI)
# 2. Save our AOI's coordinates to GeoJSON format
# 3. Create a few search filters
# 4. Search for imagery using those filters
# 5. Activate an image for downloading
# 6. Download an image

# %% [markdown]
# ### Requirements
# - Python 2.7 or 3+
# - requests
# - A [Planet API Key](https://www.planet.com/account/#/)

# %% [markdown]
# ## Define an Area of Interest

# %% [markdown]
# An **Area of Interest** (or *AOI*) is how we define the geographic "window" out of which we want to get data.
#
# For the Data API, this could be a simple bounding box with four corners, or a more complex shape, as long as the definition is in [GeoJSON](http://geojson.org/) format.
#
# For this example, let's just use a simple box. To make it easy, I'll use [geojson.io](http://geojson.io/) to quickly draw a shape & generate GeoJSON output for our box:

# %% [markdown]
# ![geojsonio.png](images/geojsonio.png)

# %% [markdown]
# We only need the "geometry" object for our Data API request:

# %%
#40.85219476715068, -96.61594635581866 ####40.85914603929872, -96.59595708657129
# Stockton, CA bounding box (created via geojson.io) 

geojson_geometry = {
  "type": "Polygon",
  "coordinates": [
          [
            [-93.6926474,41.9869467],
            [-93.6905921,41.9869545],
            [-93.6906233,41.9844974],
            [-93.6927761,41.9845267],
            [-93.6926474,41.9869467]
          ]
        ]
}

# %% [markdown]
# ## Create Filters

# %% [markdown]
# Now let's set up some **filters** to further constrain our Data API search:

# %%
# get images that overlap with our AOI 

geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": "2021-06-01T00:00:00.000Z",
    "lte": "2021-09-30T00:00:00.000Z"
  }
}

# only get images which have <50% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.1
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %% [markdown]
# ## Searching: Items and Assets

# %% [markdown]
# Planet's products are categorized as **items** and **assets**: an item is a single picture taken by a satellite at a certain time. Items have multiple asset types including the image in different formats, along with supporting metadata files.
#
# For this demonstration, let's get a satellite image that is best suited for analytic applications; i.e., a 4-band image with spectral data for Red, Green, Blue and Near-infrared values. To get the image we want, we will specify an item type of `PSScene`, and asset type `ps4b_analytic` (to get a PSScene4Band Analytic asset).
#
# You can learn more about item & asset types in Planet's Data API [here](https://developers.planet.com/docs/apis/data/items-assets/).
#
# Now let's search for all the items that match our filters:

# %%
import os
import json
import requests
from requests.auth import HTTPBasicAuth
import time
import pathlib

# API Key stored as an env variable
PLANET_API_KEY = 'PLAK6e194c14d1884f61befe389549a0252f'


item_type = "PSScene"

# API request object
search_request = {
  "item_types": [item_type], 
  "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/4be70d4b733f4bc1a7ac1dbea5c496e8/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/4be70d4b733f4bc1a7ac1dbea5c496e8/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIxLTA2LTAyVDAzOjIyOjU0LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjEwNjAxXzE2MTkzOV85N18yNDQ0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/4be70d4b733f4bc1a7ac1dbea5c496e8/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210928_170235_78_2274",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210928_170235_78_2274/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210928_170235_78_2274/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.91725587349468,
#        42.03227445758188
#       ],
#       [
#        -93.9739380846844,
#        41.83967090854702
#       ],
#       [
#        -93.54334126311363,
#        41.768654684505236
#       ],
#       [
#        -93.48569922186434,
#        41.96016277897909
#       ],
#       [
#        -93.91725587349468,
#        42.03227445758188
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210928_170235_78_2274",
#    "properties": {
#     "acquired": "2021-09-28T17:02:35.785661Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-29T04:54:46Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 102,
#     "satellite_id": "2274",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4946600",
#     "sun_azimuth": 158.5,
#     "sun_elevation": 43.7,
#     "updated": "2021-09-29T06:03:06Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210928_170233_30_2274",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210928_170233_30_2274/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210928_170233_30_2274/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.87191643141804,
#        42.18691259202676
#       ],
#       [
#        -93.9288363275138,
#        41.99434051971351
#       ],
#       [
#        -93.497249701756,
#        41.92318600436512
#       ],
#       [
#        -93.43935398185228,
#        42.11467561872262
#       ],
#       [
#        -93.87191643141804,
#        42.18691259202676
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210928_170233_30_2274",
#    "properties": {
#     "acquired": "2021-09-28T17:02:33.303741Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-29T04:54:46Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 102.1,
#     "satellite_id": "2274",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4946600",
#     "sun_azimuth": 158.6,
#     "sun_elevation": 43.6,
#     "updated": "2021-09-29T06:03:06Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 76,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210926_161319_80_2447",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210926_161319_80_2447/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210926_161319_80_2447/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.7659209271697,
#        42.104138390037114
#       ],
#       [
#        -93.8223933171833,
#        41.91609436442744
#       ],
#       [
#        -93.40177404602846,
#        41.84502799289948
#       ],
#       [
#        -93.34396397961852,
#        42.032394600596604
#       ],
#       [
#        -93.7659209271697,
#        42.104138390037114
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210926_161319_80_2447",
#    "properties": {
#     "acquired": "2021-09-26T16:13:19.801891Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-28T11:55:22Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 180.9,
#     "satellite_id": "2447",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4939716",
#     "sun_azimuth": 142.4,
#     "sun_elevation": 39.7,
#     "updated": "2021-09-29T05:17:16Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 76,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210927_161451_53_2449",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210927_161451_53_2449/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210927_161451_53_2449/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.7050736780538,
#        42.040194272965536
#       ],
#       [
#        -93.76346658796537,
#        41.85152860231172
#       ],
#       [
#        -93.33978280522973,
#        41.777235664448725
#       ],
#       [
#        -93.27980130398934,
#        41.96628452865452
#       ],
#       [
#        -93.7050736780538,
#        42.040194272965536
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210927_161451_53_2449",
#    "properties": {
#     "acquired": "2021-09-27T16:14:51.536119Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-28T04:04:43Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 277.7,
#     "satellite_id": "2449",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4943010",
#     "sun_azimuth": 142.7,
#     "sun_elevation": 39.4,
#     "updated": "2021-09-28T06:25:39Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210926_170707_48_227c",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210926_170707_48_227c/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210926_170707_48_227c/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -94.06286635091513,
#        42.10481388053266
#       ],
#       [
#        -94.12196243548767,
#        41.91322114936357
#       ],
#       [
#        -93.69047836358817,
#        41.837699960209314
#       ],
#       [
#        -93.6292576190359,
#        42.02990593715148
#       ],
#       [
#        -94.06286635091513,
#        42.10481388053266
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210926_170707_48_227c",
#    "properties": {
#     "acquired": "2021-09-26T17:07:07.488501Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-28T03:41:49Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 278.6,
#     "satellite_id": "227c",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4940332",
#     "sun_azimuth": 158.1,
#     "sun_elevation": 44.3,
#     "updated": "2021-09-29T05:17:38Z",
#     "view_angle": 5.1,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210927_161642_83_2436",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210927_161642_83_2436/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210927_161642_83_2436/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -94.01558050744465,
#        42.16500439746032
#       ],
#       [
#        -94.07293107307633,
#        41.978100564296255
#       ],
#       [
#        -93.65269050495424,
#        41.90536639840294
#       ],
#       [
#        -93.59385746600962,
#        42.092756084653246
#       ],
#       [
#        -94.01558050744465,
#        42.16500439746032
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210927_161642_83_2436",
#    "properties": {
#     "acquired": "2021-09-27T16:16:42.831649Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-28T02:44:30Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 277.1,
#     "satellite_id": "2436",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4943025",
#     "sun_azimuth": 143,
#     "sun_elevation": 39.4,
#     "updated": "2021-11-10T07:20:20Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210926_164504_0f15",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210926_164504_0f15/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210926_164504_0f15/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.92060319448683,
#        42.07357535079585
#       ],
#       [
#        -93.94257430006685,
#        42.00178409129758
#       ],
#       [
#        -93.64479715517123,
#        41.95137671240137
#       ],
#       [
#        -93.62294843553725,
#        42.02334531319209
#       ],
#       [
#        -93.92060319448683,
#        42.07357535079585
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210926_164504_0f15",
#    "properties": {
#     "acquired": "2021-09-26T16:45:04.136534Z",
#     "anomalous_pixels": 0.09,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-26T21:32:36Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 274.3,
#     "satellite_id": "0f15",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4939139",
#     "sun_azimuth": 151.5,
#     "sun_elevation": 42.7,
#     "updated": "2021-09-27T03:34:30Z",
#     "view_angle": 2,
#     "visible_confidence_percent": 99,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210925_161448_40_2212",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210925_161448_40_2212/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210925_161448_40_2212/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -94.07195476533657,
#        42.12866349975767
#       ],
#       [
#        -94.1238204256701,
#        41.94913559401876
#       ],
#       [
#        -93.72149915636224,
#        41.88435794593247
#       ],
#       [
#        -93.66885820383618,
#        42.062655165008145
#       ],
#       [
#        -94.07195476533657,
#        42.12866349975767
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210925_161448_40_2212",
#    "properties": {
#     "acquired": "2021-09-25T16:14:48.402764Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-26T01:21:18Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 101.8,
#     "satellite_id": "2212",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4936258",
#     "sun_azimuth": 142.6,
#     "sun_elevation": 40.2,
#     "updated": "2021-09-26T05:12:08Z",
#     "view_angle": 4.1,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210925_161515_95_2435",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210925_161515_95_2435/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210925_161515_95_2435/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.77397926170653,
#        42.06422127241839
#       ],
#       [
#        -93.83183106633095,
#        41.87569341909917
#       ],
#       [
#        -93.40948647698993,
#        41.8024802038467
#       ],
#       [
#        -93.35009822652631,
#        41.99085319309276
#       ],
#       [
#        -93.77397926170653,
#        42.06422127241839
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210925_161515_95_2435",
#    "properties": {
#     "acquired": "2021-09-25T16:15:15.953853Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-26T01:03:16Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 277.4,
#     "satellite_id": "2435",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4936095",
#     "sun_azimuth": 142.2,
#     "sun_elevation": 40.1,
#     "updated": "2021-09-26T04:48:50Z",
#     "view_angle": 2.9,
#     "visible_confidence_percent": 77,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210923_161631_49_2465",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210923_161631_49_2465/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210923_161631_49_2465/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.95264901369565,
#        42.13530720372203
#       ],
#       [
#        -94.00947018506258,
#        41.948706102051595
#       ],
#       [
#        -93.5914343601991,
#        41.87709703174209
#       ],
#       [
#        -93.53335215391078,
#        42.06347817446936
#       ],
#       [
#        -93.95264901369565,
#        42.13530720372203
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210923_161631_49_2465",
#    "properties": {
#     "acquired": "2021-09-23T16:16:31.498111Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-24T13:16:13Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 272.7,
#     "satellite_id": "2465",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4929733",
#     "sun_azimuth": 142,
#     "sun_elevation": 40.8,
#     "updated": "2021-11-10T07:33:48Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 76,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210922_163315_82_222f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210922_163315_82_222f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210922_163315_82_222f/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.88593958188477,
#        42.05972010208549
#       ],
#       [
#        -93.94822072456576,
#        41.88094122451284
#       ],
#       [
#        -93.54016015332579,
#        41.79864390907931
#       ],
#       [
#        -93.47631624380737,
#        41.979124078278964
#       ],
#       [
#        -93.88593958188477,
#        42.05972010208549
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210922_163315_82_222f",
#    "properties": {
#     "acquired": "2021-09-22T16:33:15.820898Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-23T03:12:04Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 180,
#     "satellite_id": "222f",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4925923",
#     "sun_azimuth": 145.8,
#     "sun_elevation": 42.4,
#     "updated": "2021-09-23T16:47:25Z",
#     "view_angle": 9.8,
#     "visible_confidence_percent": 87,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210922_163313_60_222f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210922_163313_60_222f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210922_163313_60_222f/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.84537358067254,
#        42.200561771306
#       ],
#       [
#        -93.90770171207558,
#        42.0217834997171
#       ],
#       [
#        -93.49886512174209,
#        41.93965208145662
#       ],
#       [
#        -93.43501623879348,
#        42.12008510369237
#       ],
#       [
#        -93.84537358067254,
#        42.200561771306
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210922_163313_60_222f",
#    "properties": {
#     "acquired": "2021-09-22T16:33:13.609987Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-23T03:12:04Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 180,
#     "satellite_id": "222f",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4925923",
#     "sun_azimuth": 145.9,
#     "sun_elevation": 42.3,
#     "updated": "2021-09-23T16:47:25Z",
#     "view_angle": 9.7,
#     "visible_confidence_percent": 84,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210922_161509_72_2460",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210922_161509_72_2460/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210922_161509_72_2460/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.86003255383287,
#        42.12788831134036
#       ],
#       [
#        -93.91810623206896,
#        41.9405664602702
#       ],
#       [
#        -93.49727350860651,
#        41.86679245233364
#       ],
#       [
#        -93.43762896002654,
#        42.05451451715313
#       ],
#       [
#        -93.86003255383287,
#        42.12788831134036
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210922_161509_72_2460",
#    "properties": {
#     "acquired": "2021-09-22T16:15:09.72461Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-23T01:10:44Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 276.7,
#     "satellite_id": "2460",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4925664",
#     "sun_azimuth": 141.1,
#     "sun_elevation": 40.9,
#     "updated": "2021-09-23T06:26:33Z",
#     "view_angle": 3,
#     "visible_confidence_percent": 73,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210921_161300_33_2212",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210921_161300_33_2212/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210921_161300_33_2212/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.73497926151617,
#        42.03532262768205
#       ],
#       [
#        -93.786942851168,
#        41.855737880762966
#       ],
#       [
#        -93.38458073828568,
#        41.79076879096555
#       ],
#       [
#        -93.33187373722042,
#        41.968916639386784
#       ],
#       [
#        -93.73497926151617,
#        42.03532262768205
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210921_161300_33_2212",
#    "properties": {
#     "acquired": "2021-09-21T16:13:00.333485Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-22T00:46:27Z",
#     "publishing_stage": "finalized",
#     "quality_category": "test",
#     "satellite_azimuth": 101.1,
#     "satellite_id": "2212",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4922444",
#     "sun_azimuth": 141.1,
#     "sun_elevation": 41.5,
#     "updated": "2021-09-22T05:59:02Z",
#     "view_angle": 5.1,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210921_161258_12_2212",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210921_161258_12_2212/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210921_161258_12_2212/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.69622268572147,
#        42.173230097514704
#       ],
#       [
#        -93.7482240664922,
#        41.99361182103178
#       ],
#       [
#        -93.34506106718264,
#        41.92863279840052
#       ],
#       [
#        -93.29215837873024,
#        42.106796476687265
#       ],
#       [
#        -93.69622268572147,
#        42.173230097514704
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210921_161258_12_2212",
#    "properties": {
#     "acquired": "2021-09-21T16:12:58.122573Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-22T00:46:27Z",
#     "publishing_stage": "finalized",
#     "quality_category": "test",
#     "satellite_azimuth": 101.1,
#     "satellite_id": "2212",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4922444",
#     "sun_azimuth": 141.3,
#     "sun_elevation": 41.5,
#     "updated": "2021-09-22T05:58:54Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 75,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210921_164153_1002",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210921_164153_1002/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210921_164153_1002/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.79766794567777,
#        42.05572132893588
#       ],
#       [
#        -93.81898183473504,
#        41.9847956958637
#       ],
#       [
#        -93.52317816346982,
#        41.93563527562674
#       ],
#       [
#        -93.50214111914731,
#        42.00652214168774
#       ],
#       [
#        -93.79766794567777,
#        42.05572132893588
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210921_164153_1002",
#    "properties": {
#     "acquired": "2021-09-21T16:41:53.926273Z",
#     "anomalous_pixels": 0.08,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-22T00:03:52Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 109.7,
#     "satellite_id": "1002",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4923025",
#     "sun_azimuth": 149.5,
#     "sun_elevation": 44.3,
#     "updated": "2021-09-22T06:46:14Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 99,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210919_161418_46_2436",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210919_161418_46_2436/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210919_161418_46_2436/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.82985564676123,
#        42.13734847323747
#       ],
#       [
#        -93.88574268813946,
#        41.95039452019866
#       ],
#       [
#        -93.46707821803763,
#        41.88013095292662
#       ],
#       [
#        -93.41002042776779,
#        42.06661766682359
#       ],
#       [
#        -93.82985564676123,
#        42.13734847323747
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210919_161418_46_2436",
#    "properties": {
#     "acquired": "2021-09-19T16:14:18.466015Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-09-20T02:36:10Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 110.3,
#     "satellite_id": "2436",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4915703",
#     "sun_azimuth": 140.3,
#     "sun_elevation": 42,
#     "updated": "2021-09-20T05:42:46Z",
#     "view_angle": 1.1,
#     "visible_confidence_percent": 73,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210918_161520_70_2431",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210918_161520_70_2431/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210918_161520_70_2431/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.66869905155313,
#        42.10178702175683
#       ],
#       [
#        -93.72596258133143,
#        41.915253035428634
#       ],
#       [
#        -93.30790609893278,
#        41.84296172669391
#       ],
#       [
#        -93.2493759079049,
#        42.02941356423477
#       ],
#       [
#        -93.66869905155313,
#        42.10178702175683
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210918_161520_70_2431",
#    "properties": {
#     "acquired": "2021-09-18T16:15:20.702004Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
# ...
#     "sun_elevation": 58.8,
#     "updated": "2021-06-04T08:41:50Z",
#     "view_angle": 2,
#     "visible_confidence_percent": 75,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210603_164301_1038",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210603_164301_1038/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210603_164301_1038/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.94647835868605,
#        42.038299455114654
#       ],
#       [
#        -93.96741854906794,
#        41.96686219070699
#       ],
#       [
#        -93.67090778216843,
#        41.91861739380692
#       ],
#       [
#        -93.65023299267955,
#        41.989872701372185
#       ],
#       [
#        -93.94647835868605,
#        42.038299455114654
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210603_164301_1038",
#    "properties": {
#     "acquired": "2021-06-03T16:43:01.739147Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-06-04T01:54:52Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 103,
#     "satellite_id": "1038",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4547876",
#     "sun_azimuth": 129.3,
#     "sun_elevation": 63,
#     "updated": "2021-06-04T12:38:34Z",
#     "view_angle": 2.9,
#     "visible_confidence_percent": 99,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210603_161434_19_2451",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210603_161434_19_2451/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210603_161434_19_2451/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.73138262960401,
#        42.05514047708327
#       ],
#       [
#        -93.78730656658985,
#        41.86677209092779
#       ],
#       [
#        -93.36608714732694,
#        41.79656676974911
#       ],
#       [
#        -93.3090977506248,
#        41.9842075603564
#       ],
#       [
#        -93.73138262960401,
#        42.05514047708327
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210603_161434_19_2451",
#    "properties": {
#     "acquired": "2021-06-03T16:14:34.195358Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-06-04T00:34:01Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 103.8,
#     "satellite_id": "2451",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4547020",
#     "sun_azimuth": 119.5,
#     "sun_elevation": 58.8,
#     "updated": "2021-06-04T05:10:05Z",
#     "view_angle": 2,
#     "visible_confidence_percent": 73,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210602_162411_15_2264",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210602_162411_15_2264/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210602_162411_15_2264/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -94.04460198331421,
#        42.190194908611694
#       ],
#       [
#        -94.10002091893458,
#        42.0013218013081
#       ],
#       [
#        -93.67623485566367,
#        41.93221465071329
#       ],
#       [
#        -93.61979717534551,
#        42.11934099124211
#       ],
#       [
#        -94.04460198331421,
#        42.190194908611694
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210602_162411_15_2264",
#    "properties": {
#     "acquired": "2021-06-02T16:24:11.151965Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 98,
#     "cloud_cover": 0.01,
#     "cloud_percent": 1,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-06-03T10:13:29Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 101.9,
#     "satellite_id": "2264",
#     "shadow_percent": 1,
#     "snow_ice_percent": 0,
#     "strip_id": "4544194",
#     "sun_azimuth": 123,
#     "sun_elevation": 60.2,
#     "updated": "2021-06-03T16:15:31Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 87,
#     "visible_percent": 99
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210602_161824_46_245c",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210602_161824_46_245c/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210602_161824_46_245c/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.71523308912728,
#        42.05037515752166
#       ],
#       [
#        -93.77302538626392,
#        41.863196187204224
#       ],
#       [
#        -93.35233312146259,
#        41.789497133185996
#       ],
#       [
#        -93.29284289187449,
#        41.97734006264065
#       ],
#       [
#        -93.71523308912728,
#        42.05037515752166
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210602_161824_46_245c",
#    "properties": {
#     "acquired": "2021-06-02T16:18:24.461647Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 91,
#     "cloud_cover": 0.06,
#     "cloud_percent": 6,
#     "ground_control": true,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-06-03T05:32:39Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 277.8,
#     "satellite_id": "245c",
#     "shadow_percent": 4,
#     "snow_ice_percent": 0,
#     "strip_id": "4544369",
#     "sun_azimuth": 120.2,
#     "sun_elevation": 58.9,
#     "updated": "2021-06-03T08:58:38Z",
#     "view_angle": 3.9,
#     "visible_confidence_percent": 76,
#     "visible_percent": 94
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210601_161425_64_2212",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210601_161425_64_2212/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210601_161425_64_2212/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.70292132116771,
#        42.043260698817754
#       ],
#       [
#        -93.75445253270516,
#        41.86457970705725
#       ],
#       [
#        -93.35459873162053,
#        41.79999497566757
#       ],
#       [
#        -93.30211047171042,
#        41.97748553523589
#       ],
#       [
#        -93.70292132116771,
#        42.043260698817754
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210601_161425_64_2212",
#    "properties": {
#     "acquired": "2021-06-01T16:14:25.6498Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-06-02T03:49:29Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 101.8,
#     "satellite_id": "2212",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4540132",
#     "sun_azimuth": 120.1,
#     "sun_elevation": 58.8,
#     "updated": "2021-06-02T06:34:54Z",
#     "view_angle": 4.1,
#     "visible_confidence_percent": 73,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20210601_161939_97_2444",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20210601_161939_97_2444/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20210601_161939_97_2444/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_sr:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#    ],
#    "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_sr",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -93.91843426099496,
#        42.099331387044295
#       ],
#       [
#        -93.97720097280131,
#        41.91129671062777
#       ],
#       [
#        -93.55353377646571,
#        41.836381753108135
#       ],
#       [
#        -93.49300098164699,
#        42.025095276317714
#       ],
#       [
#        -93.91843426099496,
#        42.099331387044295
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20210601_161939_97_2444",
#    "properties": {
#     "acquired": "2021-06-01T16:19:39.974965Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 4.1,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-06-02T03:22:54Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 278.5,
#     "satellite_id": "2444",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "4539817",
#     "sun_azimuth": 120.5,
#     "sun_elevation": 58.8,
#     "updated": "2021-06-02T05:06:03Z",
#     "view_angle": 5.2,
#     "visible_confidence_percent": 72,
#     "visible_percent": 100
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %% [markdown]
# Our search returns metadata for all of the images within our AOI that match our date range and cloud coverage filters. It looks like there are multiple images here; let's extract a list of just those image IDs:

# %%
def download_order(order_url, img_id, auth, overwrite=False):
    r = requests.get(order_url, auth=auth)
    print(r)
 
    response = r.json()
    deadcount = 0
#     while(response['basic_analytic_4b']['status'] == "inactive"):
#         deadcount +=1
    print("Reponse is:",response['ortho_analytic_8b']['status'])

    results = response['ortho_analytic_8b']['_links']
    #links = result.json()[u"basic_analytic_4b"]["_links"]
    self_link = results["_self"]
    activation_link = results["activate"]
    
    # Request activation of the 'analytic' asset:
    activate_result = \
      requests.get(
        activation_link,
        auth=HTTPBasicAuth(PLANET_API_KEY, '')
      )
    start = time.time()
    activation_status_result = \
      requests.get(
        self_link,
        auth=HTTPBasicAuth(PLANET_API_KEY, '')
      )
    
    while(activation_status_result.json()["status"] == "activating"):
        end = time.time()
        elapse = end - start
        if elapse == 100:
            print('returning due to timeout')
            return False
    print("Asset is:",activation_status_result.json()["status"])
    path = pathlib.Path(os.path.join('data', img_id))
    url = activation_status_result.json()["location"]
    print(path)
    print('{} items to download'.format(len(url)))
    
    if overwrite or not path.exists():
        print('downloading {} to {}'.format(img_id, path))
        r = requests.get(url, allow_redirects=True)
        path.parent.mkdir(parents=True, exist_ok=True)
        open(path, 'wb').write(r.content)
    else:
        print('{} already exists, skipping {}'.format(path, img_id))
            
    return True

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(len(image_ids))
#print(image_ids)
# Out:
# 148

# %% [markdown]
# Since we just want a single image, and this is only a demonstration, for our purposes here we can arbitrarily select the first image in that list. Let's do that, and get the `asset` list available for that image:

# %%
# For demo purposes, just grab the first image ID
for cnt in range(len(image_ids)):
    id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, image_ids[cnt])
    completed = download_order(id0_url,image_ids[cnt],auth=HTTPBasicAuth(PLANET_API_KEY, ''))
    if completed == True:
        print("downloaded:", cnt)
    # Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
#     result = \
#       requests.get(
#         id0_url,
#         auth=HTTPBasicAuth(PLANET_API_KEY, '')
#       )

#     # List of asset types available for this particular satellite image
#     print(result.json().keys())
#     print(result.json()['basic_analytic_4b']['status'])
#     # Parse out useful links
#     links = result.json()[u"basic_analytic_4b"]["_links"]
#     self_link = links["_self"]
#     activation_link = links["activate"]

#     # Request activation of the 'analytic' asset:
#     activate_result = \
#       requests.get(
#         activation_link,
#         auth=HTTPBasicAuth(PLANET_API_KEY, '')
#       )
#     activation_status_result = \
#       requests.get(
#         self_link,
#         auth=HTTPBasicAuth(PLANET_API_KEY, '')
#       )

#     print(activation_status_result.json()["status"])
# Out:
# <Response [200]>
# Reponse is: activating
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-2c4739d85c89> in <module>
#       2 for cnt in range(len(image_ids)):
#       3     id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, image_ids[cnt])
# ----> 4     completed = download_order(id0_url,image_ids[cnt],auth=HTTPBasicAuth(PLANET_API_KEY, ''))
#       5     if completed == True:
#       6         print("downloaded:", cnt)
#
# <ipython-input-23-d99ff45469fd> in download_order(order_url, img_id, auth, overwrite)
#      27       )
#      28
# ---> 29     while(activation_status_result.json()["status"] == "activating"):
#      30         end = time.time()
#      31         elapse = end - start
#
# /opt/conda/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     888                 try:
#     889                     return complexjson.loads(
# --> 890                         self.content.decode(encoding), **kwargs
#     891                     )
#     892                 except UnicodeDecodeError:
#
# /opt/conda/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344
#     345     if (cls is None and object_hook is None and
# --> 346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
#     348         return _default_decoder.decode(s)
#
# KeyboardInterrupt:

# %% [markdown]
#  ## Activation and Downloading
#
# The Data API does not pre-generate assets, so they are not always immediately availiable to download. In order to download an asset, we first have to **activate** it.
#
# Remember, earlier we decided we wanted a color-corrected image best suited for *analytic* applications. We can check the status of the PSScene 4-Band analytic asset we want to download like so:

# %%
# This is "inactive" if the "analytic" asset has not yet been activated; otherwise 'active'
print(result.json()['basic_analytic_4b']['status'])
# Out:
# inactive

# %% [markdown]
# Let's now go ahead and **activate** that asset for download:

# %%
# Parse out useful links
links = result.json()[u"basic_analytic_4b"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'analytic' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %% [markdown]
# At this point, we wait for the activation status for the asset we are requesting to change from `inactive` to `active`. We can monitor this by polling the "status" of the asset:

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# activating

# %% [markdown]
# Once the asset has finished activating (status is "active"), we can download it.
#
# *Note: the download link on an active asset is temporary*

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-0e5415f917b1> in <module>
#       1 # Image can be downloaded by making a GET with your Planet API key, from here:
# ----> 2 download_link = activation_status_result.json()["location"]
#       3 print(download_link)
#
# KeyError: 'location'

# %% [markdown]
# ![stockton_thumb.png](images/stockton_thumb.png)
